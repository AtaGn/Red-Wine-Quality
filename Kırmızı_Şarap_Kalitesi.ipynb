# %% [markdown]
# # **Kırmızı Şarap Kalitesi**

# %% [markdown]
# # **Veri Analizi ve Makine Öğrenimi**
# **Veri Analizi**, toplanan veriler üzerinden anlamlı bilgiler, öngörüler ve sonuçlar çıkarabilmek için yapılan işlemlerin bütünüdür. Temel istatistiksel analizlerden başlayarak, veri görselleştirme ve keşifsel veri analizi (EDA) gibi teknikleri içerir. Bu süreç, verilerin temizlenmesi, dönüştürülmesi ve modelleme için uygun hale getirilmesi gibi adımları da barındırır.
#
# **Makine Öğrenimi (Machine Learning - ML)**, algoritmalar ve istatistiksel modeller yardımıyla bilgisayarların deneyim kazanarak öğrenmesini sağlayan yapay zeka (AI) dalıdır. Makine öğrenimi, verilerden öğrenerek tahminlerde bulunma veya kararlar alma kapasitesine sahip modeller geliştirmek için kullanılır.
#
# ## **Kullanılan Makine Öğrenimi Modelleri**
# 1. **Lojistik Regresyon (Logistic Regression)**
# Lojistik Regresyon, bağımlı değişkenin kategorik olduğu durumlarda kullanılan ve sonucu olasılık cinsinden veren bir regresyon modelidir. Özellikle ikili sınıflandırma problemlerinde tercih edilir. Model, verilen bağımsız değişkenlere göre sonucun olma olasılığını hesaplar.
#
# 2. **KNeighbors Sınıflandırıcı (KNeighborsClassifier)**
# K-En Yakın Komşu (KNN), bir veri noktasını, en yakın k komşusunun çoğunluk sınıfına göre sınıflandıran temel bir sınıflandırma algoritmasıdır. Uzaklık ölçütleri (genellikle Öklid mesafesi) kullanılarak, yeni bir veri noktasının, mevcut veri noktalarına olan yakınlığına göre sınıfı tahmin edilir.
#
# 3. **Destek Vektör Makineleri (Support Vector Classifier - SVC)**
# Destek Vektör Makineleri, verileri en iyi ayıran hiper-düzlemi bulmaya çalışan güçlü ve esnek bir sınıflandırma modelidir. SVC, özellikle verilerin doğrusal olarak ayrılamadığı durumlar için çekirdek hileleri (kernel tricks) kullanarak etkili sonuçlar elde edebilir.
#
# 4. **Karar Ağacı Sınıflandırıcısı (DecisionTree Classifier)**
# Karar Ağaçları, kararlar ve olası sonuçları, rastgele olayları, maliyetleri ve faydaları ağaç yapıları olarak modelleyen bir sınıflandırma ve regresyon modelidir. Ağaç, karar düğümleri ve yaprak düğümlerden oluşur, her karar düğümü bir öznitelik üzerinden bir testi temsil eder.
#
# 5. **Rastgele Orman Sınıflandırıcısı (RandomForest Classifier)**
# Rastgele Orman, birden fazla karar ağacını birleştirerek çalışan bir ansamble öğrenme tekniğidir. Her bir karar ağacı biraz farklı veri alt kümeleri üzerinde eğitilir ve sonuçta, bireysel ağaçların tahminlerinin ortalaması alınarak daha kararlı ve doğru tahminler elde edilir.
#
# Bu modeller, makine öğrenimi uygulamalarında geniş bir kullanım alanına sahiptir ve çeşitli gerçek dünya problemlerinin çözümünde etkili sonuçlar sağlamaktadır. Ben de bu çalışmamda bunları kullanacağım.

# %% [markdown]
# # Veriyi İndirme

# %% [markdown]
# Kullanacağımız veriyi link aracılığıyla indirebiliriz bu şekilde.

# %%
import requests
import zipfile
from io import BytesIO

# URL for the CSV file (ZIP format)
urls = []
urls.append("https://storage.googleapis.com/kaggle-data-sets/4458/8204/bundle/archive.zip?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20240504%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20240504T182407Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=...")


for url in urls:
  # Send a GET request to the URL
  response = requests.get(url)

  # Open the ZIP file from the response
  with zipfile.ZipFile(BytesIO(response.content)) as thezip:
      # Extract the contained CSV to the current directory
      thezip.extractall()

  print("CSV file downloaded and extracted.")
# Out:
# CSV file downloaded and extracted.

# %% [markdown]
# # Veri Analizi

# %% [markdown]
# ## **Veri Analizi Nedir?**
# Veri Analizi, toplanan verilerden anlam çıkararak bilgiye dönüştürme sürecidir. Bu süreç, verilerin toplanmasından, işlenmesine, analiz edilmesine ve sonuçların sunulmasına kadar geniş bir yelpazede faaliyetleri kapsar. Veri analizi, iş dünyasından bilime, finanstan sağlığa kadar pek çok alanda karar verme süreçlerini destekler ve optimize eder.
#
# ### **Veri Analizinin Aşamaları**
# 1. **Veri Toplama**
#
# Veri toplama, analizin temelini oluşturur. Bu aşamada, analiz edilecek veriler çeşitli kaynaklardan toplanır. Veri kaynakları arasında anketler, sensörler, dijital platformlar ve halka açık veri setleri bulunabilir.
#
# 2. **Veri Temizleme ve Hazırlama**
#
# Toplanan veriler genellikle eksik, hatalı veya tutarsız olabilir. Veri temizleme, bu tür sorunları düzelten süreçler bütünüdür. Veri hazırlama ise, verileri analiz için uygun hale getirmeyi içerir; bu, verilerin dönüştürülmesi, normalleştirilmesi ve uygun formatlara sokulması işlemlerini kapsar.
#
# 3. **Keşifsel Veri Analizi (EDA)**
#
# EDA, verilerin yapısal özelliklerini ve ana hatlarını keşfetmek için yapılan analizlerdir. Veri görselleştirme teknikleri bu aşamada sıklıkla kullanılır. Histogramlar, kutu grafikleri ve saçılım diyagramları gibi araçlar, veri setindeki eğilimleri ve düzensizlikleri ortaya çıkarmak için kullanılır.
#
# 4. **İleri Veri Analizi**
#
# Bu aşama, veriler üzerinde istatistiksel testler yapılmasını, makine öğrenimi modellerinin eğitilmesini ve hipotezlerin test edilmesini içerir. İleri analiz, verilerden daha derin bilgiler elde etmek ve öngörülerde bulunmak için kullanılır.
#
# 5. **Raporlama ve Görselleştirme**
#
# Analiz sürecinin sonucunda elde edilen bilgiler, çeşitli raporlama ve görselleştirme teknikleri ile son kullanıcılara sunulur. Bu teknikler, karar verme süreçlerini destekleyecek şekilde tasarlanmış olup, grafikler, interaktif tablolar ve dashboardlar şeklinde olabilir.
#
# **Veri Analizinin Önemi**
# Veri analizi, işletmelerin ve organizasyonların daha bilinçli kararlar almasını sağlar. Pazar trendlerini anlama, müşteri davranışlarını öngörme, operasyonel verimliliği artırma ve risk yönetimi gibi pek çok alanda kritik rol oynar. Günümüzde veri biliminin ve büyük verinin yükselişi ile birlikte, veri analizi her zamankinden daha stratejik bir öneme sahiptir.

# %% [markdown]
# ## Kullanacağımız Kütüphaneleri İndiriyoruz

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from matplotlib.ticker import FormatStrFormatter

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn.tree import DecisionTreeClassifier ,export_graphviz
import graphviz
from IPython.display import Image  # To plot decision tree.

# %% [markdown]
# ## **Veri Analizi ve Görselleştirme**

# %%
df = pd.read_csv('/content/winequality-red.csv')
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %% [markdown]
# Boş(null) değer var mı diye kontrol ediyoruz

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %% [markdown]
# Sayıları Yuvarlıyoruz

# %%
display(np.round(df.describe()))
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count         1599.0            1599.0       1599.0          1599.0
# mean             8.0               1.0          0.0             3.0
# std              2.0               0.0          0.0             1.0
# min              5.0               0.0          0.0             1.0
# 25%              7.0               0.0          0.0             2.0
# 50%              8.0               1.0          0.0             2.0
# 75%              9.0               1.0          0.0             3.0
# max             16.0               2.0          1.0            16.0
#
#        chlorides  free sulfur dioxide  total sulfur dioxide  density      pH  \
# count     1599.0               1599.0                1599.0   1599.0  1599.0
# mean         0.0                 16.0                  46.0      1.0     3.0
# std          0.0                 10.0                  33.0      0.0     0.0
# ...

# %%
df.groupby('quality').count()
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality
# 3                   10                10           10              10
# 4                   53                53           53              53
# 5                  681               681          681             681
# 6                  638               638          638             638
# 7                  199               199          199             199
# 8                   18                18           18              18
#
#          chlorides  free sulfur dioxide  total sulfur dioxide  density   pH  \
# quality
# 3               10                   10                    10       10   10
# 4               53                   53                    53       53   53
# 5              681                  681                   681      681  681
# 6              638                  638                   638      638  638
# 7              199                  199                   199      199  199
# ...

# %%
null_columns=df.columns[df.isnull().any()]
print(null_columns)
# Out:
# Index([], dtype='object')

# %% [markdown]
# Heatmap çıkartıyoruz

# %%
plt.figure(figsize=(10,5))
heatmap = sns.heatmap(df.corr(), annot=True, fmt=".1f", cmap="Reds")
heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=12)
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=12)
plt.show()

# %%
cols_sns = ['residual sugar', 'chlorides', 'density', 'pH', 'alcohol', 'quality']
sns.set(style="ticks")
sns.pairplot(df[cols_sns],hue="quality")

# %%
features = ["fixed acidity", "volatile acidity", "citric acid", "residual sugar", "chlorides",
            "free sulfur dioxide", "total sulfur dioxide", "density", "pH", "sulphates", "alcohol"]

fig = plt.figure(figsize=(16,8))
for i in range(len(features)):
    ax1 = fig.add_subplot(3, 4, i+1)
    ax1.xaxis.set_major_formatter(FormatStrFormatter('%.2f'))
    ax1.yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
    sns.boxplot(x='quality', y=features[i], data=df,palette="Set3")
    i = i + 1
plt.subplots_adjust(hspace = 0.5)
plt.subplots_adjust(wspace = 0.5)
plt.show()

# %%
fig = plt.figure(figsize = (10,6))
sns.barplot(x='quality', y='sulphates',data=df)

# %%
from sklearn.preprocessing import LabelEncoder
bins = (2, 5.5, 8)
group_names = ['bad', 'good']
df['quality'] = pd.cut(df['quality'], bins = bins, labels = group_names)

label_quality = LabelEncoder()
df['quality'] = label_quality.fit_transform(df['quality'])
df['quality'].value_counts()
# Out:
# 1    855
# 0    744
# Name: quality, dtype: int64

# %%
X = df.drop('quality', axis=1)
y = df['quality']

X_train, X_test, y_train, y_test = train_test_split(X, y,test_size = 0.2)

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.fit_transform(X_test)

# %%
print("X_train {0} , X_test {1} " .format(X_train.shape , X_test.shape))
# Out:
# X_train (1279, 11) , X_test (320, 11)

# %% [markdown]
# # **LogisticRegression**

# %%
#------------------------######### LogisticRegression #######-----------------
lrg_classifier = LogisticRegression(solver='newton-cg',tol= 0.0001,C= 0.5,)
lrg_classifier.fit(X_train, y_train.ravel())

cv_lr = cross_val_score(estimator = lrg_classifier, X = X_train, y = y_train.ravel(), cv = 10)
print("CV: ", cv_lr.mean())

lt_y_pred_train = lrg_classifier.predict(X_train)
accuracy_lr_train = accuracy_score(y_train, lt_y_pred_train)
print("Training set accuracy for Logistic Regression: ", accuracy_lr_train)

y_pred_lr_test = lrg_classifier.predict(X_test)
accuracy_lr_test = accuracy_score(y_test, y_pred_lr_test)
print("Test set accuracy for Logistic Regression: ", accuracy_lr_test)
# Out:
# CV:  0.7436085137795276
# Training set accuracy for Logistic Regression:  0.7513682564503519
# Test set accuracy for Logistic Regression:  0.73125

# %%
lrg_classifier.fit(X_train, y_train)
lr_y_pred_test = lrg_classifier.predict(X_test)

print(classification_report(y_test, lr_y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.74      0.71       144
#            1       0.77      0.73      0.75       176
#
#     accuracy                           0.73       320
#    macro avg       0.73      0.73      0.73       320
# weighted avg       0.73      0.73      0.73       320

# %%
confusion_matrix(y_test, lr_y_pred_test)

tp_lr = confusion_matrix(y_test, lr_y_pred_test)[0,0]
fp_lr = confusion_matrix(y_test, lr_y_pred_test)[0,1]
tn_lr = confusion_matrix(y_test, lr_y_pred_test)[1,1]
fn_lr = confusion_matrix(y_test, lr_y_pred_test)[1,0]

# %% [markdown]
# # **KNeighbors**

# %%
#------------------------#########  KNeighbors #######-----------------
from sklearn.neighbors import KNeighborsClassifier
knn_classifier = KNeighborsClassifier(leaf_size = 1, metric = 'minkowski', n_neighbors = 28, weights = 'distance')
knn_classifier.fit(X_train, y_train.ravel())
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=1, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=28, p=2,
#                      weights='distance')

# %%
# Çapraz Doğrulama Puanını Tahmin Etme
knn_cv = cross_val_score(estimator = knn_classifier, X = X_train, y = y_train.ravel(), cv = 10)
print("CV: ", knn_cv.mean())

knn_y_pred_train = knn_classifier.predict(X_train)
knn_accuracy_train = accuracy_score(y_train, knn_y_pred_train)
print("Training set accuracy for KNN: ", knn_accuracy_train)

knn_y_pred_test = knn_classifier.predict(X_test)
knn_accuracy_test = accuracy_score(y_test, knn_y_pred_test)
print("Test set accuracy for KNN: ", knn_accuracy_test)
# Out:
# CV:  0.7920398622047244
# Training set accuracy for KNN:  1.0
# Test set accuracy for KNN:  0.753125

# %%
confusion_matrix(y_test, knn_y_pred_test)

tp_knn = confusion_matrix(y_test, knn_y_pred_test)[0,0]
fp_knn = confusion_matrix(y_test, knn_y_pred_test)[0,1]
tn_knn = confusion_matrix(y_test, knn_y_pred_test)[1,1]
fn_knn = confusion_matrix(y_test, knn_y_pred_test)[1,0]

# %% [markdown]
# # **KNeighbors**

# %%
#------------------------#########  SVC #######-----------------
from sklearn.svm import SVC
svm_linear_classifier = SVC(kernel = 'linear')
svm_linear_classifier.fit(X_train, y_train.ravel())
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='linear',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
svm_linear_cv = cross_val_score(estimator = svm_linear_classifier, X = X_train, y = y_train.ravel(), cv = 10)
print("CV: ", svm_linear_cv.mean())

svm_linear_train_y_pred = svm_linear_classifier.predict(X_train)

svm_linear_accuracy_train = accuracy_score(y_train, svm_linear_train_y_pred)
print("Training set accuracy for SVC: ", svm_linear_accuracy_train)

svm_linear_y_pred_test = svm_linear_classifier.predict(X_test)
svm_linear_accuracy_test = accuracy_score(y_test, svm_linear_y_pred_test)
print("Test set accuracy for SVC: ", svm_linear_accuracy_test)
# Out:
# CV:  0.7459399606299213
# Training set accuracy for SVC:  0.7521501172791243
# Test set accuracy for SVC:  0.740625

# %%
confusion_matrix(y_test, svm_linear_y_pred_test)

tp_svm_linear = confusion_matrix(y_test, svm_linear_y_pred_test)[0,0]
fp_svm_linear = confusion_matrix(y_test, svm_linear_y_pred_test)[0,1]
tn_svm_linear = confusion_matrix(y_test, svm_linear_y_pred_test)[1,1]
fn_svm_linear = confusion_matrix(y_test, svm_linear_y_pred_test)[1,0]

# %% [markdown]
# # **DecisionTree Classifier**

# %%
#------------------------#########  DecisionTree Classifier #######-----------------

dt_classifier = DecisionTreeClassifier(criterion = 'gini', max_features=6, max_leaf_nodes=400, random_state = 33, max_depth=4)
dt_classifier.fit(X_train, y_train.ravel())
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=4, max_features=6, max_leaf_nodes=400,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=33, splitter='best')

# %%
dt_cv = cross_val_score(estimator = dt_classifier, X = X_train, y = y_train.ravel(), cv = 10)
print("CV: ", dt_cv.mean())

dt_y_pred_train = dt_classifier.predict(X_train)
dt_accuracy_train = accuracy_score(y_train, dt_y_pred_train)
print("Training set accuracy for DecisionTree: ", dt_accuracy_train)

dt_y_pred_test = dt_classifier.predict(X_test)
dt_accuracy_test = accuracy_score(y_test, dt_y_pred_test)
print("Test set accuracy for DecisionTree: ", dt_accuracy_test)
# Out:
# CV:  0.7216904527559056
# Training set accuracy for DecisionTree:  0.764659890539484
# Test set accuracy for DecisionTree:  0.721875

# %%
confusion_matrix(y_test, dt_y_pred_test)

tp_dt = confusion_matrix(y_test, dt_y_pred_test)[0,0]
fp_dt = confusion_matrix(y_test, dt_y_pred_test)[0,1]
tn_dt = confusion_matrix(y_test, dt_y_pred_test)[1,1]
fn_dt = confusion_matrix(y_test, dt_y_pred_test)[1,0]

# %%
data = export_graphviz(dt_classifier,out_file=None,feature_names=list(X.columns.values),class_names=None,
                         filled=True, rounded=True,
                         special_characters=True,proportion=True)

graph = graphviz.Source(data)
graph

# %% [markdown]
# # **RandomForest Classifier**

# %%
#------------------------#########  RandomForest Classifier #######-----------------
from sklearn.ensemble import RandomForestClassifier
rf_classifier = RandomForestClassifier(criterion = 'entropy', max_features = 4, n_estimators = 800, random_state=33)
rf_classifier.fit(X_train, y_train.ravel())
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='entropy', max_depth=None, max_features=4,
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=800,
#                        n_jobs=None, oob_score=False, random_state=33, verbose=0,
#                        warm_start=False)

# %%
# Çapraz Doğrulama Puanını Tahmin Etme
rf_cv = cross_val_score(estimator = rf_classifier, X = X_train, y = y_train.ravel(), cv = 10)
print("CV: ", rf_cv.mean())

rf_y_pred_train = rf_classifier.predict(X_train)
rf_accuracy_train = accuracy_score(y_train, rf_y_pred_train)
print("Training set: ", rf_accuracy_train)

rf_y_pred_test = rf_classifier.predict(X_test)
rf_accuracy_test = accuracy_score(y_test, rf_y_pred_test)
print("Test set: ", rf_accuracy_test)
# Out:
# CV:  0.8217827263779528
# Training set:  1.0
# Test set:  0.809375

# %%
#..--------Rastgele Ormanın Önemli Özellikleri
feature_importances = pd.DataFrame(rf_classifier.feature_importances_,
                                   index = X.columns,columns=['importance']).sort_values('importance', ascending=False)
print(feature_importances)
# Out:
#                       importance
# alcohol                 0.182877
# sulphates               0.124862
# volatile acidity        0.111237
# total sulfur dioxide    0.102494
# density                 0.084003
# chlorides               0.075607
# pH                      0.069411
# fixed acidity           0.066414
# citric acid             0.066155
# free sulfur dioxide     0.059734
# residual sugar          0.057205

# %%
importance = pd.DataFrame({'Importance': rf_classifier.feature_importances_}, index=X.columns)
importance.sort_values('Importance', axis=0, ascending=True).plot(kind='barh', color='r')
plt.xlabel('Variable importance')
plt.legend(loc='lower right')
plt.legend()
plt.show()

# %%
confusion_matrix(y_test, rf_y_pred_test)

tp_rf = confusion_matrix(y_test, rf_y_pred_test)[0,0]
fp_rf = confusion_matrix(y_test, rf_y_pred_test)[0,1]
tn_rf = confusion_matrix(y_test, rf_y_pred_test)[1,1]
fn_rf = confusion_matrix(y_test, rf_y_pred_test)[1,0]

# %% [markdown]
# # **Farklı Doğruluk ve Çapraz Doğrulama modelleri arasındaki karşılaştırma.**

# %%
#------------
###-----------Farklı Doğruluk ve Çapraz Doğrulama modelleri arasındaki karşılaştırma.

models = [('Logistic Regression', tp_lr, fp_lr, tn_lr, fn_lr, accuracy_lr_train, accuracy_lr_test, cv_lr.mean()),
          ('K-Nearest Neighbors (KNN)', tp_knn, fp_knn, tn_knn, fn_knn, knn_accuracy_train, knn_accuracy_test, knn_cv.mean()),
          ('SVM', tp_svm_linear, fp_svm_linear, tn_svm_linear, fn_svm_linear, svm_linear_accuracy_train, svm_linear_accuracy_test, svm_linear_cv.mean()),
          ('Decision Tree Classification', tp_dt, fp_dt, tn_dt, fn_dt, dt_accuracy_train, dt_accuracy_test, dt_cv.mean()),
          ('Random Forest Tree Classification', tp_rf, fp_rf, tn_rf, fn_rf, rf_accuracy_train, rf_accuracy_test, rf_cv.mean())
         ]

predict = pd.DataFrame(data = models, columns=['Model', 'True Positive', 'False Positive', 'True Negative','False Negative', 'Accuracy(training)', 'Accuracy(test)',
                                               'Cross-Validation'])
predict
# Out:
#                                Model  True Positive  False Positive  \
# 0                Logistic Regression            106              38
# 1          K-Nearest Neighbors (KNN)            107              37
# 2                                SVM            113              31
# 3       Decision Tree Classification            108              36
# 4  Random Forest Tree Classification            116              28
#
#    True Negative  False Negative  Accuracy(training)  Accuracy(test)  \
# 0            128              48            0.751368        0.731250
# 1            134              42            1.000000        0.753125
# 2            124              52            0.752150        0.740625
# 3            123              53            0.764660        0.721875
# 4            143              33            1.000000        0.809375
#
#    Cross-Validation
# 0          0.743609
# 1          0.792040
# 2          0.745940
# 3          0.721690
# 4          0.821783

# %%
f, axes = plt.subplots(2,1, figsize=(14,10))
predict.sort_values(by=['Accuracy(training)'], ascending=False, inplace=True)
sns.barplot(x='Accuracy(training)', y='Model', data = predict, palette='Blues_d', ax = axes[0])
#axes[0].set(xlabel='Region', ylabel='Charges')
axes[0].set_xlabel('Accuracy (Training)', size=16)
axes[0].set_ylabel('Model')
axes[0].set_xlim(0,1.0)
axes[0].set_xticks(np.arange(0, 1.1, 0.1))
predict.sort_values(by=['Accuracy(test)'], ascending=False, inplace=True)
sns.barplot(x='Accuracy(test)', y='Model', data = predict, palette='Reds_d', ax = axes[1])
#axes[0].set(xlabel='Region', ylabel='Charges')
axes[1].set_xlabel('Accuracy (Test)', size=16)
axes[1].set_ylabel('Model')
axes[1].set_xlim(0,1.0)
axes[1].set_xticks(np.arange(0, 1.1, 0.1))
plt.show()

# %% [markdown]
# **Tüm modelleri karşılaştırdığımızda RF sınıflandırıcının daha iyi sonuçlar ürettiğini gözlemliyoruz.**
